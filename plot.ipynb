# %%
import numpy as np
import matplotlib.pyplot as plt

path = './outputs/UE4 and Airsim/'

ImDDPG_reward_env2 = np.load(path + 'ImDDPG_env2/results/train_ma_rewards.npy')
DDPG_reward_env2 = np.load(path + 'DDPG_env2/results/train_ma_rewards.npy')

plt.plot(ImDDPG_reward_env2, label='ImDDPG')
plt.plot(DDPG_reward_env2, label='DDPG')
plt.title('Training Reward')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend()
# Out:
# 執行具有 'yolov7 (Python 3.7.12)' 的儲存格需要 ipykernel 套件。
#
# 執行下列命令以將 'ipykernel' 安裝到 Python 環境中。
#
# 命令: 'conda install -n yolov7 ipykernel --update-deps --force-reinstall'

# %%
ImDDPG_reward_env2_v2 = np.load(path + '20231226-110756/results/train_ma_rewards.npy')
DDPG_reward_env2_v2 = np.load(path + 'DDPG_env3_random/results/train_ma_rewards.npy')

plt.plot(ImDDPG_reward_env2_v2, label='ImDDPG')
plt.plot(DDPG_reward_env2_v2, label='DDPG')
plt.title('Training Reward')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend()
